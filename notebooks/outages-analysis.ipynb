# %%
import pandas as pd
import geopandas as gdp
import seaborn as sns
import matplotlib.pyplot as plt

# %%
outages = gdp.read_file('../data/outages/unplanned-outages.geojson')

outages.head()
# Out:
#    incident_duration exceptional_event_id network_type  customer_affected  \
# 0               1976                 None           HV                4.0
# 1                101                 None           HV               28.0
# 2                  3                 None           HV              667.0
# 3                 85                 None           HV                2.0
# 4                 76                 None           HV                1.0
#
#      direct_cause_category                                       direct_cause  \
# 0  Unclassified or Unknown                                      Cause Unknown
# 1  Unclassified or Unknown                        Transient Fault - No Repair
# 2                Companies  Interruption to remove local generator or rest...
# 3  Unclassified or Unknown                                      Cause Unknown
# 4  Unclassified or Unknown                        Transient Fault - No Repair
#
#    district_code district_name        incident_date_time  \
# 0             41       Preston 2019-09-10 16:51:00+00:00
# 1             41       Preston 2019-09-18 19:21:00+00:00
# 2             41       Preston 2019-09-19 01:46:00+00:00
# 3             41       Preston 2019-09-20 15:25:00+00:00
# 4             41       Preston 2019-09-20 21:43:00+00:00
#
#     restoration_date_time  ...  \
# 0  2019/09/12 02:47:00+01  ...
# 1  2019/09/18 22:02:00+01  ...
# 2  2019/09/19 02:49:00+01  ...
# 3  2019/09/20 17:50:00+01  ...
# 4  2019/09/20 23:59:00+01  ...
#
#                         main_equipment_involved_2  main_equipment_involved_3  \
# 0  Indoor, Kiosk, Underground S/S, Pit or Chamber  Transformer (excluding 5)
# 1             Above 25Al/16Cu and up to 50Al/32Cu                  Aluminium
# 2                           Mixed or unclassified                       None
# 3             Above 25Al/16Cu and up to 50Al/32Cu             Copper Cadmium
# 4             Above 25Al/16Cu and up to 50Al/32Cu                  Aluminium
#
#      main_equipment_involved_4 main_equipment_involved_5  \
# 0      No lightning protection                      None
# 1  Single Circuit - Horizontal                      None
# 2                         None                      None
# 3  Single Circuit - Horizontal                      None
# 4  Single Circuit - Horizontal                      None
#
#   main_equipment_involved_6 primary_substation incident_reference_number  \
# 0                      None             400399                    100117
# 1                      None             400225                    100120
# 2                      None             400413                    100123
# 3                      None             400101                    100124
# 4                      None             400219                    100125
#
#   voltage total_customer_minutes_lost                   geometry
# 0     6.6                        1420  POINT (-2.65839 53.79097)
# 1      11                        2828  POINT (-2.62659 53.64815)
# 2     6.6                        2001  POINT (-2.72402 53.77329)
# 3     6.6                         170  POINT (-2.99573 53.74652)
# 4      11                          76  POINT (-2.71868 53.68913)
#
# [5 rows x 24 columns]

# %%
outages.columns
# Out:
# Index(['incident_duration', 'exceptional_event_id', 'network_type',
#        'customer_affected', 'direct_cause_category', 'direct_cause',
#        'district_code', 'district_name', 'incident_date_time',
#        'restoration_date_time', 'exceptional_event_enddate',
#        'exceptional_event_start_date', 'incident_reporting_year',
#        'main_equipment_involved_1', 'main_equipment_involved_2',
#        'main_equipment_involved_3', 'main_equipment_involved_4',
#        'main_equipment_involved_5', 'main_equipment_involved_6',
#        'primary_substation', 'incident_reference_number', 'voltage',
#        'total_customer_minutes_lost', 'geometry'],
#       dtype='object')

# %%
outages = outages.drop(columns=['district_code', 'main_equipment_involved_2', 'main_equipment_involved_3',
                                                 'main_equipment_involved_4', 'main_equipment_involved_5', 'main_equipment_involved_6', 'incident_reference_number'])
outages.head()
# Out:
#    incident_duration exceptional_event_id network_type  customer_affected  \
# 0               1976                 None           HV                4.0
# 1                101                 None           HV               28.0
# 2                  3                 None           HV              667.0
# 3                 85                 None           HV                2.0
# 4                 76                 None           HV                1.0
#
#      direct_cause_category                                       direct_cause  \
# 0  Unclassified or Unknown                                      Cause Unknown
# 1  Unclassified or Unknown                        Transient Fault - No Repair
# 2                Companies  Interruption to remove local generator or rest...
# 3  Unclassified or Unknown                                      Cause Unknown
# 4  Unclassified or Unknown                        Transient Fault - No Repair
#
#   district_name        incident_date_time   restoration_date_time  \
# 0       Preston 2019-09-10 16:51:00+00:00  2019/09/12 02:47:00+01
# 1       Preston 2019-09-18 19:21:00+00:00  2019/09/18 22:02:00+01
# 2       Preston 2019-09-19 01:46:00+00:00  2019/09/19 02:49:00+01
# 3       Preston 2019-09-20 15:25:00+00:00  2019/09/20 17:50:00+01
# 4       Preston 2019-09-20 21:43:00+00:00  2019/09/20 23:59:00+01
#
#   exceptional_event_enddate exceptional_event_start_date  \
# 0                      None                          NaT
# 1                      None                          NaT
# 2                      None                          NaT
# 3                      None                          NaT
# 4                      None                          NaT
#
#   incident_reporting_year          main_equipment_involved_1  \
# 0                    2019  POWER TRANSFORMERS, REACTORS ETC.
# 1                    2019                     OVERHEAD LINES
# 2                    2019            MISCELLANEOUS EQUIPMENT
# 3                    2019                     OVERHEAD LINES
# 4                    2019                     OVERHEAD LINES
#
#   primary_substation voltage  total_customer_minutes_lost  \
# 0             400399     6.6                         1420
# 1             400225      11                         2828
# 2             400413     6.6                         2001
# 3             400101     6.6                          170
# 4             400219      11                           76
#
#                     geometry
# 0  POINT (-2.65839 53.79097)
# 1  POINT (-2.62659 53.64815)
# 2  POINT (-2.72402 53.77329)
# 3  POINT (-2.99573 53.74652)
# 4  POINT (-2.71868 53.68913)

# %%
outages['direct_cause_category'].unique()
# Out:
# array(['Unclassified or Unknown', 'Companies', 'Third Party',
#        'Weather and Environment', 'Birds, Animals and Insects',
#        'Generating Company or NGC', None], dtype=object)

# %%
outages['direct_cause'].unique()
# Out:
# array(['Cause Unknown', 'Transient Fault - No Repair',
#        'Interruption to remove local generator or restore temporary connection (where in use > 18 hours)',
#        'by Other Third Parties', 'Operational or Safety Restriction',
#        'Flooding', 'Birds (including Swans and Geese)',
#        'by Water/Sewage Company or their Contractors',
#        'by Private Developers or their Contractors',
#        'Deterioration due to Ageing or Wear (excluding corrosion)',
#        'Causes Unclassified in this Table',
#        'by Private Individuals (excluding 49 and 56)',
#        'Extension of Fault Zone due to Fault Switching (including ASC held faults)',
#        'Wind and Gale (excluding Windborne Material)',
#        'Falling live trees (not felled)',
#        'Incorrect or Unsuitable protection Settings or Fuse Rating',
#        'Local Generation Failure (Isolated System)',
#        'Fire not due to Faults',
#        'Corrosion due to atmosphere/ environment', 'Corrosion',
#        'involving Farm Workers or Farm Implements',
#        'Farm and Domestic Animals',
#        "Extension of Fault Zone due to incorrect operation of equipment (includes slow opening CB'S)",
#        'Load Current above Previous Assessment', 'Lightning',
#        'by Unknown Third Parties', 'No Fault Found',
#        'Vermin, Wild Animals and Insects', 'Growing Trees', 'Solar Heat',
#        'Rain', 'Unsuitable Paralleling Conditions',
#        'Mechanical Shock or Vibration',
#        'Inadequate or Faulty Maintenance',
#        'by Highway Authorities or their Contractors',
#        'Accidental Contact, Damage or Interference by Cable TV companies or their contractors',
#        'Windborne Materials',
#        'Fault on Equipment Faulting Adjacent Equipment',
#        'Accidental Contact, Damage or Interference by DNOC or their Contractors (including Live Line Work)',
#        'Failure of EHV or HV infeed from Adjacent DNO',
#        'involving Aircraft or Unmanned Balloons',
#        'Incorrect Application of DNOC Equipment',
#        'Incorrect or Inadequate System Records, Circuit Labelling or Identification',
#        'Wilful Damage, Interference (not including Metal Theft)',
#        'Ground Subsidence',
#        'Fault on customers network causing operation of Network Protection',
#        'Involving Leisure Pursuits', 'Falling dead tree', 'Metal Theft',
#        'by Gas Company or their Contractors',
#        'Unsuitable Protection Characteristics',
#        'Snow, Sleet and Blizzard',
#        'Faulty Manufacturing, Design, Assembly or Materials',
#        'by Local Building Authorities or their Contractors', 'Ice',
#        'by Public Telecommunications Operator or their Contractors (eg BT or Mercury)',
#        'Switching Error by DNOC Personnel',
#        'Incorrect application of equipment by Contractors',
#        'Testing or Commissioning Error by DNOC Staff',
#        'Faulty Installation or Construction by DNOC Staff',
#        'Faulty installation or Construction by Contractors',
#        'Premature Insulation Failure',
#        'Airborne Deposits (excluding Windborne Material)', 'Condensation',
#        'Failure of Supply From Generating Company or the National Grid',
#        'Failure of 132KV infeed from Adjacent DNO',
#        'By Cable TV Companies or their contractors',
#        'Corrosion due to Bi-Metal Contact',
#        'Growing or Falling Trees (not felled)',
#        'DNO Equipment affected by Private Generator or Authorised Electricity Operator (other than National Grid)',
#        'Inadequate Rupturing or Short Circuit Capacity',
#        'Freezing Fog and Frost',
#        'Disruption of Intended Indoor Environment',
#        'Testing or commissioning error by Contractors',
#        'DNO Equipment Affected by National Grid Personnel or Equipment',
#        'Switching Error by Contractors', 'NONE',
#        'Failure of EHV/HV infeed from Adjacent District of Same DNO'],
#       dtype=object)

# %%
plt.figure(figsize=(14, 8))
sns.barplot(data=outages, x='total_customer_minutes_lost', y='direct_cause_category', palette='viridis')
plt.title('Direct Cause Category by Total Customer Minutes Lost')
plt.xlabel('Total Customer Minutes Lost')
plt.ylabel('Direct Cause Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(14, 8))
sns.barplot(data=outages, x='customer_affected', y='direct_cause_category', palette='viridis')
plt.title('Direct Cause Category by Customers Affected')
plt.xlabel('Customers Affected')
plt.ylabel('Direct Cause Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(14, 8))
sns.barplot(data=outages, x='incident_duration', y='direct_cause_category', palette='viridis')
plt.title('Direct Cause Category by Incident Duration')
plt.xlabel('Incident Duration (minutes)')
plt.ylabel('Direct Cause Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/0r/fyrm13815xg5dtcft5cgtlt00000gn/T/ipykernel_10360/2833925305.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=outages, x='total_customer_minutes_lost', y='direct_cause_category', palette='viridis')
# /var/folders/0r/fyrm13815xg5dtcft5cgtlt00000gn/T/ipykernel_10360/2833925305.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=outages, x='customer_affected', y='direct_cause_category', palette='viridis')
# /var/folders/0r/fyrm13815xg5dtcft5cgtlt00000gn/T/ipykernel_10360/2833925305.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=outages, x='incident_duration', y='direct_cause_category', palette='viridis')

# %%
weather_and_environment = outages[outages['direct_cause_category'] == 'Weather and Environment']
weather_and_environment.head()
# Out:
#     incident_duration exceptional_event_id network_type  customer_affected  \
# 17              34828                 None           HV               26.0
# 41                273                 None           HV               13.0
# 42                325                   40           HV              125.0
# 43                277                   40           HV               35.0
# 44                417                   40           HV              450.0
#
#       direct_cause_category                                  direct_cause  \
# 17  Weather and Environment                                      Flooding
# 41  Weather and Environment  Wind and Gale (excluding Windborne Material)
# 42  Weather and Environment  Wind and Gale (excluding Windborne Material)
# 43  Weather and Environment  Wind and Gale (excluding Windborne Material)
# 44  Weather and Environment  Wind and Gale (excluding Windborne Material)
#
#    district_name        incident_date_time   restoration_date_time  \
# 17       Preston 2019-11-12 12:02:00+00:00  2019/12/06 16:30:00+00
# 41       Preston 2020-02-08 09:53:00+00:00  2020/02/08 14:26:00+00
# 42       Preston 2020-02-09 20:01:00+00:00  2020/02/10 01:26:00+00
# 43       Preston 2020-02-09 21:44:00+00:00  2020/02/10 02:21:00+00
# 44       Preston 2020-02-09 10:15:00+00:00  2020/02/09 17:12:00+00
#
#    exceptional_event_enddate exceptional_event_start_date  \
# 17                      None                          NaT
# 41                      None                          NaT
# 42            20200225105500    2020-02-08 21:50:00+00:00
# 43            20200225105500    2020-02-08 21:50:00+00:00
# 44            20200225105500    2020-02-08 21:50:00+00:00
#
#    incident_reporting_year         main_equipment_involved_1  \
# 17                    2019  SWITCHGEAR, FUSEGEAR AND BUSBARS
# 41                    2019                    OVERHEAD LINES
# 42                    2019                    OVERHEAD LINES
# 43                    2019                    OVERHEAD LINES
# 44                    2019                    OVERHEAD LINES
#
#    primary_substation voltage  total_customer_minutes_lost  \
# 17             400116      11                         3077
# 41             400407     6.6                         3549
# 42             400216      11                        40625
# 43             400213      11                         5783
# 44             400210      11                        63365
#
#                      geometry
# 17  POINT (-3.00233 53.87086)
# 41  POINT (-2.87668 53.76907)
# 42  POINT (-2.70433 53.61422)
# 43  POINT (-2.83798 53.69527)
# 44  POINT (-2.88846 53.56679)

# %%
plt.figure(figsize=(14, 8))
sns.barplot(data=weather_and_environment, x='total_customer_minutes_lost', y='direct_cause', palette='viridis')
plt.title('Direct Cause by Total Customer Minutes Lost')
plt.xlabel('Total Customer Minutes Lost')
plt.ylabel('Direct Cause')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(14, 8))
sns.barplot(data=weather_and_environment, x='customer_affected', y='direct_cause', palette='viridis')
plt.title('Direct Cause by Customers Affected')
plt.xlabel('Customers Affected')
plt.ylabel('Total Customers Affected')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(14, 8))
sns.barplot(data=weather_and_environment, x='incident_duration', y='direct_cause', palette='viridis')
plt.title('Direct Cause by Incident Duration')
plt.xlabel('Incident Duration (minutes)')
plt.ylabel('Direct Cause')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/0r/fyrm13815xg5dtcft5cgtlt00000gn/T/ipykernel_10360/3423456123.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=weather_and_environment, x='total_customer_minutes_lost', y='direct_cause', palette='viridis')
# /var/folders/0r/fyrm13815xg5dtcft5cgtlt00000gn/T/ipykernel_10360/3423456123.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=weather_and_environment, x='customer_affected', y='direct_cause', palette='viridis')
# /var/folders/0r/fyrm13815xg5dtcft5cgtlt00000gn/T/ipykernel_10360/3423456123.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=weather_and_environment, x='incident_duration', y='direct_cause', palette='viridis')

# %%
outages['direct_cause_category'].value_counts()
# Out:
# direct_cause_category
# Companies                     121584
# Unclassified or Unknown        94486
# Weather and Environment        45568
# Third Party                    29288
# Birds, Animals and Insects      2830
# Generating Company or NGC        398
# Name: count, dtype: int64

# %%
flooding = outages[outages['direct_cause'] == 'Flooding']
flooding.head()
# Out:
#      incident_duration exceptional_event_id network_type  customer_affected  \
# 17               34828                 None           HV               26.0
# 110                 28                   40           HV             1663.0
# 628                103                 None           HV                2.0
# 887                472                 None           HV              440.0
# 926              16669                 None           HV               89.0
#
#        direct_cause_category direct_cause district_name  \
# 17   Weather and Environment     Flooding       Preston
# 110  Weather and Environment     Flooding     Blackburn
# 628  Weather and Environment     Flooding        Ashton
# 887  Weather and Environment     Flooding        Kendal
# 926  Weather and Environment     Flooding        Kendal
#
#            incident_date_time   restoration_date_time  \
# 17  2019-11-12 12:02:00+00:00  2019/12/06 16:30:00+00
# 110 2020-02-09 15:34:00+00:00  2020/02/09 16:02:00+00
# 628 2021-01-20 19:55:00+00:00  2021/01/21 16:00:00+00
# 887 2020-08-11 04:16:00+00:00  2020/08/11 13:08:00+01
# 926 2020-11-01 22:15:00+00:00  2020/11/13 12:04:00+00
#
#     exceptional_event_enddate exceptional_event_start_date  \
# 17                       None                          NaT
# 110            20200225105500    2020-02-08 21:50:00+00:00
# 628                      None                          NaT
# 887                      None                          NaT
# 926                      None                          NaT
#
#     incident_reporting_year          main_equipment_involved_1  \
# 17                     2019   SWITCHGEAR, FUSEGEAR AND BUSBARS
# 110                    2019   SWITCHGEAR, FUSEGEAR AND BUSBARS
# 628                    2020   SWITCHGEAR, FUSEGEAR AND BUSBARS
# 887                    2020   SWITCHGEAR, FUSEGEAR AND BUSBARS
# 926                    2020  POWER TRANSFORMERS, REACTORS ETC.
#
#     primary_substation voltage  total_customer_minutes_lost  \
# 17              400116      11                         3077
# 110             400071      11                        46564
# 628             302963      11                          103
# 887             609910      11                        41605
# 926             609958      11                        21934
#
#                       geometry
# 17   POINT (-3.00233 53.87086)
# 110  POINT (-2.32926 53.79468)
# 628  POINT (-2.09708 53.41315)
# 887  POINT (-2.79657 54.01873)
# 926   POINT (-2.6118 54.13908)

# %%
flooding.count()
# Out:
# incident_duration               981
# exceptional_event_id            729
# network_type                    981
# customer_affected               981
# direct_cause_category           981
# direct_cause                    981
# district_name                   981
# incident_date_time              981
# restoration_date_time           981
# exceptional_event_enddate       729
# exceptional_event_start_date    729
# incident_reporting_year         981
# main_equipment_involved_1       981
# primary_substation              979
# voltage                         981
# total_customer_minutes_lost     981
# geometry                        973
# dtype: int64

# %%
flooding.isnull().sum()

flooding['exceptional_event_id'].fillna(0, inplace=True)
# Out:
# /var/folders/0r/fyrm13815xg5dtcft5cgtlt00000gn/T/ipykernel_10360/1103655877.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   flooding['exceptional_event_id'].fillna(0, inplace=True)
# /var/folders/0r/fyrm13815xg5dtcft5cgtlt00000gn/T/ipykernel_10360/1103655877.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flooding['exceptional_event_id'].fillna(0, inplace=True)

# %%
cause_counts = flooding['main_equipment_involved_1'].value_counts()
print(cause_counts)
# Out:
# main_equipment_involved_1
# Underground Main - PLCS (armoured or unarmoured)                                  321
# MISCELLANEOUS EQUIPMENT                                                           121
# SWITCHGEAR, FUSEGEAR AND BUSBARS                                                   94
# Underground Main - Mixed or unclassified                                           87
# Underground Main - Consac                                                          70
# Switchgear/Fusegear (excl. service cut-outs)  - S/S fuseboard or pillar            67
# Switchgear/Fusegear (excl. service cut-outs)  - Link-box                           38
# Underground Service (metered) - PLCS                                               35
# Other - Underground service cut-out (metered)                                      30
# POWER TRANSFORMERS, REACTORS ETC.                                                  23
# PROTECTION EQUIPMENT                                                               18
# OVERHEAD LINES                                                                     15
# Switchgear/Fusegear (excl. service cut-outs)  - Pole-mounted fusegear              13
# POWER CABLES                                                                       10
# Underground Service (metered) - Plastics insulated concentric types                 9
# Underground Main - Waveform                                                         7
# Other                                                                               4
# Switchgear/Fusegear (excl. service cut-outs)  - Multi-service pillar or turret      3
# Other - Overhead service cut-out (metered)                                          3
# Underground Main - Districable                                                      2
# Switchgear/Fusegear (excl. service cut-outs)  - Other                               2
# Overhead main - Insulated conductors                                                1
# Overhead service (metered) - Other                                                  1
# Switchgear/Fusegear (excl. service cut-outs)  - Street feeder pillar                1
# Unmetered service - Underground                                                     1
# Switchgear/Fusegear (excl. service cut-outs)  - Circuit breaker                     1
# Surface wiring main                                                                 1
# Overhead main - Bare conductors                                                     1
# Overhead main - Mixed                                                               1
# Underground Service (metered) - Districable                                         1
# Name: count, dtype: int64

# %%
underground_main = flooding[flooding['main_equipment_involved_1'].isin([
    'Underground Main - PLCS (armoured or unarmoured)',
    'Underground Main - Mixed or unclassified',
    'Underground Main - Consac',
    'Underground Main - Waveform',
    'Underground Service (metered) - Plastics insulated concentric types'
])]

# %%
underground_main.head()
# Out:
#        incident_duration exceptional_event_id network_type  customer_affected  \
# 11990                302                    0           LV               50.0
# 15791                987                    0           LV               26.0
# 21168                 60                    0           LV                1.0
# 21207                 10                    0           LV                5.0
# 24747                 56                   31           LV               13.0
#
#          direct_cause_category direct_cause district_name  \
# 11990  Weather and Environment     Flooding      Carlisle
# 15791  Weather and Environment     Flooding     Stockport
# 21168  Weather and Environment     Flooding    Manchester
# 21207  Weather and Environment     Flooding    Manchester
# 24747  Weather and Environment     Flooding    Manchester
#
#              incident_date_time   restoration_date_time  \
# 11990 2000-09-20 13:43:00+00:00  2000/09/20 19:45:00+01
# 15791 2006-03-09 05:23:00+00:00  2006/03/09 21:50:00+00
# 21168 2024-11-14 14:30:00+00:00  2024/11/14 15:30:00+00
# 21207 2025-01-01 13:30:00+00:00  2025/01/03 13:30:00+00
# 24747 2015-12-14 18:10:00+00:00  2015/12/14 19:06:00+00
#
#       exceptional_event_enddate exceptional_event_start_date  \
# 11990                      None                          NaT
# 15791                      None                          NaT
# 21168                      None                          NaT
# 21207                      None                          NaT
# 24747            20151217185000    2015-12-04 19:20:00+00:00
#
#       incident_reporting_year  \
# 11990                    2000
# 15791                    2005
# 21168                    2024
# 21207                    2024
# 24747                    2015
#
#                                main_equipment_involved_1 primary_substation  \
# 11990   Underground Main - PLCS (armoured or unarmoured)             636397
# 15791   Underground Main - PLCS (armoured or unarmoured)             331472
# 21168  Underground Service (metered) - Plastics insul...             166894
# 21207                          Underground Main - Consac             171943
# 24747                          Underground Main - Consac             171157
#
#       voltage  total_customer_minutes_lost                   geometry
# 11990      LV                         6210  POINT (-2.99096 54.84109)
# 15791      LV                        20004  POINT (-2.14516 53.29354)
# 21168      LV                           60  POINT (-2.21434 53.49032)
# 21207      LV                           50  POINT (-2.24904 53.41516)
# 24747      LV                          728                       None

# %%
underground_main['main_equipment_involved_1'].value_counts()
# Out:
# main_equipment_involved_1
# Underground Main - PLCS (armoured or unarmoured)                       321
# Underground Main - Mixed or unclassified                                87
# Underground Main - Consac                                               70
# Underground Service (metered) - Plastics insulated concentric types      9
# Underground Main - Waveform                                              7
# Name: count, dtype: int64

# %%
underground_main['network_type'].value_counts()
# Out:
# network_type
# LV    494
# Name: count, dtype: int64

# %%
underground_main['voltage'].value_counts()
# Out:
# voltage
# LV    494
# Name: count, dtype: int64

# %%
underground_main = underground_main.drop(columns=['network_type', 'voltage', 'incident_reporting_year'])

# %%
underground_main.head()
# Out:
#        incident_duration exceptional_event_id  customer_affected  \
# 11990                302                    0               50.0
# 15791                987                    0               26.0
# 21168                 60                    0                1.0
# 21207                 10                    0                5.0
# 24747                 56                   31               13.0
#
#          direct_cause_category direct_cause district_name  \
# 11990  Weather and Environment     Flooding      Carlisle
# 15791  Weather and Environment     Flooding     Stockport
# 21168  Weather and Environment     Flooding    Manchester
# 21207  Weather and Environment     Flooding    Manchester
# 24747  Weather and Environment     Flooding    Manchester
#
#              incident_date_time   restoration_date_time  \
# 11990 2000-09-20 13:43:00+00:00  2000/09/20 19:45:00+01
# 15791 2006-03-09 05:23:00+00:00  2006/03/09 21:50:00+00
# 21168 2024-11-14 14:30:00+00:00  2024/11/14 15:30:00+00
# 21207 2025-01-01 13:30:00+00:00  2025/01/03 13:30:00+00
# 24747 2015-12-14 18:10:00+00:00  2015/12/14 19:06:00+00
#
#       exceptional_event_enddate exceptional_event_start_date  \
# 11990                      None                          NaT
# 15791                      None                          NaT
# 21168                      None                          NaT
# 21207                      None                          NaT
# 24747            20151217185000    2015-12-04 19:20:00+00:00
#
#                                main_equipment_involved_1 primary_substation  \
# 11990   Underground Main - PLCS (armoured or unarmoured)             636397
# 15791   Underground Main - PLCS (armoured or unarmoured)             331472
# 21168  Underground Service (metered) - Plastics insul...             166894
# 21207                          Underground Main - Consac             171943
# 24747                          Underground Main - Consac             171157
#
#        total_customer_minutes_lost                   geometry
# 11990                         6210  POINT (-2.99096 54.84109)
# 15791                        20004  POINT (-2.14516 53.29354)
# 21168                           60  POINT (-2.21434 53.49032)
# 21207                           50  POINT (-2.24904 53.41516)
# 24747                          728                       None

# %%
underground_main['exceptional_event_id'].value_counts()
# Out:
# exceptional_event_id
# 31    252
# 32    196
# 0      44
# 34      2
# Name: count, dtype: int64

# %%
underground_main.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 494 entries, 11990 to 285415
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   incident_duration             494 non-null    int32
#  1   exceptional_event_id          494 non-null    object
#  2   customer_affected             494 non-null    float64
#  3   direct_cause_category         494 non-null    object
#  4   direct_cause                  494 non-null    object
#  5   district_name                 494 non-null    object
#  6   incident_date_time            494 non-null    datetime64[ms, UTC]
#  7   restoration_date_time         494 non-null    object
#  8   exceptional_event_enddate     450 non-null    object
#  9   exceptional_event_start_date  450 non-null    datetime64[ms, UTC]
#  10  main_equipment_involved_1     494 non-null    object
#  11  primary_substation            494 non-null    object
#  12  total_customer_minutes_lost   494 non-null    int32
#  13  geometry                      492 non-null    geometry
# dtypes: datetime64[ms, UTC](2), float64(1), geometry(1), int32(2), object(8)
# memory usage: 54.0+ KB

# %%
underground_main['exceptional_event_id'] = underground_main['exceptional_event_id'].astype('category')
underground_main['direct_cause_category'] = underground_main['direct_cause_category'].astype('category')
underground_main['direct_cause'] = underground_main['direct_cause'].astype('category')
underground_main['main_equipment_involved_1'] = underground_main['main_equipment_involved_1'].astype('category')
underground_main['district_name'] = underground_main['incident_duration'].astype('category')
underground_main['primary_substation'] = underground_main['primary_substation'].astype('category')


underground_main['restoration_date_time'] = pd.to_datetime(underground_main['restoration_date_time'], utc=True)
underground_main['exceptional_event_enddate'] = pd.to_datetime(underground_main['exceptional_event_enddate'], utc=True)

# %%
underground_main.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 494 entries, 11990 to 285415
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   incident_duration             494 non-null    int32
#  1   exceptional_event_id          494 non-null    category
#  2   customer_affected             494 non-null    float64
#  3   direct_cause_category         494 non-null    category
#  4   direct_cause                  494 non-null    category
#  5   district_name                 494 non-null    category
#  6   incident_date_time            494 non-null    datetime64[ms, UTC]
#  7   restoration_date_time         494 non-null    datetime64[ns, UTC]
#  8   exceptional_event_enddate     450 non-null    datetime64[ns, UTC]
#  9   exceptional_event_start_date  450 non-null    datetime64[ms, UTC]
#  10  main_equipment_involved_1     494 non-null    category
#  11  primary_substation            494 non-null    category
#  12  total_customer_minutes_lost   494 non-null    int32
#  13  geometry                      492 non-null    geometry
# dtypes: category(6), datetime64[ms, UTC](2), datetime64[ns, UTC](2), float64(1), geometry(1), int32(2)
# memory usage: 53.5 KB

# %%
underground_main.head()
# Out:
#        incident_duration exceptional_event_id  customer_affected  \
# 11990                302                    0               50.0
# 15791                987                    0               26.0
# 21168                 60                    0                1.0
# 21207                 10                    0                5.0
# 24747                 56                   31               13.0
#
#          direct_cause_category direct_cause district_name  \
# 11990  Weather and Environment     Flooding           302
# 15791  Weather and Environment     Flooding           987
# 21168  Weather and Environment     Flooding            60
# 21207  Weather and Environment     Flooding            10
# 24747  Weather and Environment     Flooding            56
#
#              incident_date_time     restoration_date_time  \
# 11990 2000-09-20 13:43:00+00:00 2000-09-20 18:45:00+00:00
# 15791 2006-03-09 05:23:00+00:00 2006-03-09 21:50:00+00:00
# 21168 2024-11-14 14:30:00+00:00 2024-11-14 15:30:00+00:00
# 21207 2025-01-01 13:30:00+00:00 2025-01-03 13:30:00+00:00
# 24747 2015-12-14 18:10:00+00:00 2015-12-14 19:06:00+00:00
#
#       exceptional_event_enddate exceptional_event_start_date  \
# 11990                       NaT                          NaT
# 15791                       NaT                          NaT
# 21168                       NaT                          NaT
# 21207                       NaT                          NaT
# 24747 2015-12-17 18:50:00+00:00    2015-12-04 19:20:00+00:00
#
#                                main_equipment_involved_1 primary_substation  \
# 11990   Underground Main - PLCS (armoured or unarmoured)             636397
# 15791   Underground Main - PLCS (armoured or unarmoured)             331472
# 21168  Underground Service (metered) - Plastics insul...             166894
# 21207                          Underground Main - Consac             171943
# 24747                          Underground Main - Consac             171157
#
#        total_customer_minutes_lost                   geometry
# 11990                         6210  POINT (-2.99096 54.84109)
# 15791                        20004  POINT (-2.14516 53.29354)
# 21168                           60  POINT (-2.21434 53.49032)
# 21207                           50  POINT (-2.24904 53.41516)
# 24747                          728                       None

# %%
underground_main.to_file('../data/outages/ug-outage-flooding.geojson', driver='GeoJSON')
