# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
region = gpd.read_file("data/boundary/uk-power-networks-boundary.geojson")

region.info()

grid_primary_sites = gpd.read_file("data/primary-sites/grid-and-primary-sites.geojson")

grid_primary_sites.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   geo_point_2d  1 non-null      object
#  1   name          1 non-null      object
#  2   analytics     1 non-null      float64
#  3   last_updat    1 non-null      datetime64[ms, UTC]
#  4   geometry      1 non-null      geometry
# dtypes: datetime64[ms, UTC](1), float64(1), geometry(1), object(2)
# memory usage: 172.0+ bytes
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sitefunctionallocation  1500 non-null   object
#  1   licencearea             1500 non-null   object
#  2   sitename                1500 non-null   object
#  3   sitetype                1500 non-null   object
#  4   sitevoltage             1500 non-null   int32
#  5   esqcroverallrisk        1500 non-null   object
#  6   gridref                 1500 non-null   object
#  7   siteassetcount          1500 non-null   int32
#  8   powertransformercount   1500 non-null   int32
#  9   electricalassetcount    1500 non-null   int32
#  10  civilassetcount         1500 non-null   int32
#  11  street                  835 non-null    object
#  12  suburb                  297 non-null    object
#  13  towncity                1468 non-null   object
#  14  county                  1500 non-null   object
#  15  postcode                1500 non-null   object
#  16  yearcommissioned        1500 non-null   object
#  17  datecommissioned        1500 non-null   datetime64[ms]
#  18  siteclassification      1500 non-null   object
#  19  assessmentdate          1431 non-null   datetime64[ms]
#  20  last_report             1500 non-null   object
#  21  calculatedresistance    1500 non-null   object
#  22  measuredresistance_ohm  1133 non-null   float64
#  23  next_assessmentdate     1494 non-null   datetime64[ms]
#  24  easting                 1500 non-null   object
#  25  northing                1500 non-null   object
#  26  transratingwinter       1500 non-null   object
#  27  transratingsummer       1500 non-null   object
#  28  reversepower            1500 non-null   object
#  29  maxdemandsummer         1500 non-null   object
#  30  maxdemandwinter         1500 non-null   object
#  31  local_authority         1500 non-null   object
#  32  local_authority_code    1500 non-null   object
#  33  what3words              1500 non-null   object
#  34  geometry                1500 non-null   geometry
# dtypes: datetime64[ms](3), float64(1), geometry(1), int32(5), object(25)
# memory usage: 381.0+ KB

# %%
fig, ax = plt.subplots(figsize=(10, 8))

region.plot(ax=ax, edgecolor='black', facecolor='orange', linewidth=1, label="UK Power Networks Boundary")

grid_primary_sites.plot(ax=ax, edgecolor='orange', facecolor='red', linewidth=1, linestyle='-', label="Overlay Layer", markersize=10)

plt.title("UK Power Networks Boundary with Substation Locations")
plt.legend()
plt.show()
# Out:
# /var/folders/0r/fyrm13815xg5dtcft5cgtlt00000gn/T/ipykernel_66294/3041668906.py:8: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend()

# %%
flood_history = gpd.read_file("data/flood-history/Historic_Flood_MapPolygon.shp")

fig, ax = plt.subplots(figsize=(10, 8))

flood_history.plot(ax=ax, edgecolor='blue', facecolor='blue', linewidth=1, linestyle='-', label="Flood History", alpha=0.5)

plt.title("UK Historic Flood Map")
plt.legend()
plt.show()
# Out:
# /var/folders/0r/fyrm13815xg5dtcft5cgtlt00000gn/T/ipykernel_66294/324878985.py:8: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend()
# /var/folders/0r/fyrm13815xg5dtcft5cgtlt00000gn/T/ipykernel_66294/324878985.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
